# %%
import importlib

import support as sp
import explore as exp
importlib.reload(sp)
importlib.reload(exp)
# Out:
# <module 'explore' from '/Users/miron/Desktop/Diploma/analysis/diplomus/explore.py'>

# %%
# словарь глубин станций
dict_of_depths = {
    'A01':2039,
    'A02':2011,
    'A03':2063,
    'A04':2054,
    'B05':1998,
    'B06':2499,
    'B07':1980,
    'B08':1924,
    'C09':3511,
    'C10':4247,
    'C11':4378,
    'C12':3784,
    'D13':2441,
    'D14':2350,
    'D15':1909,
    'D16':1970,
    'E17':2054,
    'E18':2052,
    'E19':1909,
    'E20':1977,
    'C21':4449,
    'E22':1841,
}

# %% [markdown]
# # 2017-01-22

# %% [markdown]
# - P_time_start = 10, 0
# - P_time_stop = 24, 0
# - Az_time_start = 10, 30
# - Az_time_stop = 16, 30

# %%
P_time_start = 10, 0
P_time_stop = 24, 0
Az_time_start = 10, 30
Az_time_stop = 16, 30

# %% [markdown]
# ## A01 - отлично(0.88, 0.09)

# %%
station_name = 'A01'
Az_path = 'data/az_metrics/201701221030_6h/M.KMA01.ZL.10Hz.asc'
P_path = 'data/p_metrics/201701221000_14h/M.KMA01.Pr'
height = dict_of_depths[station_name]
start_point = 125000

explorer = exp.StationExplorer(station_name, height, Az_path, P_path, P_time_start, P_time_stop, Az_time_start, Az_time_stop, period=1, start_point=start_point)
explorer.run()
# Out:
# Время начала измерений: 10-0
# Время конца измерений: 24-0
# Проверка на равенство дополненных промежутков: True
# Доля хороших частот = 0.885
# Дельта = 0.096

# %% [markdown]
# ## A02 - хорошо(0.70, 0.12)

# %%
station_name = 'A02'
Az_path = 'data/az_metrics/201701221030_6h/M.KMA02.ZL.10Hz.asc'
P_path = 'data/p_metrics/201701221000_14h/M.KMA02.Pr'
height = dict_of_depths[station_name]
start_point = 125000

explorer = exp.StationExplorer(station_name, height, Az_path, P_path, P_time_start, P_time_stop, Az_time_start, Az_time_stop, period=1, start_point=start_point)
explorer.run()
# Out:
# Время начала измерений: 10-0
# Время конца измерений: 24-0
# Проверка на равенство дополненных промежутков: True
# Доля хороших частот = 0.705
# Дельта = 0.126
