# %%
import importlib

import support as sp
import explore as exp
import constants as cn
importlib.reload(sp)
importlib.reload(exp)
importlib.reload(cn)
# Out:
# <module 'constants' from '/Users/miron/Desktop/Diploma/analysis/diplomus/constants.py'>

# %% [markdown]
# # 2018-01-23

# %% [markdown]
# - P_time_start = 13, 0
# - P_time_stop = 24, 0
# - Az_time_start = 15, 35
# - Az_time_stop = 21, 35

# %% [markdown]
# ## A01 - отлично (1.00, 0.09)

# %%
station_name = 'A01'
height = 2039
Az_path = 'data/az_metrics/201801231535_6h/M.KMA01.ZL.10Hz.asc.txt'
P_path = 'data/p_metrics/201801231300_11h/M.KMA01.Pr.txt'
P_time_start = 13, 0
P_time_stop = 24, 0
Az_time_start = 15, 35
Az_time_stop = 21, 35
start_point = 200000

explorer = exp.StationExplorer(station_name, height, Az_path, P_path, P_time_start, P_time_stop, Az_time_start, Az_time_stop, period=1, start_point=start_point)
explorer.run()
# Out:
# Время начала измерений: 13-0
# Время конца измерений: 24-0
# Проверка на равенство дополненных промежутков: True
# Доля хороших частот = 1.0
# Дельта = 0.086
